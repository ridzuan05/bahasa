# %%
import pandas as pd

# %%
df = pd.read_excel('news.xlsx')

# %%
df.head()
# Out:
#                                                Title  \
# 0  Ia memalukan! - Neymar bidas keputusan penalti...
# 1    Suspek kes pembunuhan Nur Aisyah direman 7 hari
# 2  " Pas, saya tidak bayar Rewcastle Brown RM1.4j...
# 3  Masih bantu BN menunjukkan Pas parti munafik -...
# 4  " Aiman ada masalah komunikasi, tapi dia ada p...
#
#                                                 Text
# 0  PENYERANG Paris Saint-Germain (PSG), Neymar, b...
# 1  LANGKAWI : Sepasang suami isteri yang juga sus...
# 2  KUALA TERENGGANU : Presiden Pas, Datuk Seri Ab...
# 3  HULU LANGAT : Tindakan Pas yang masih membantu...
# 4  SEMENYIH : Presiden Parti Pribumi Bersatu Mala...

# %%
print(df['Text'].apply(lambda x: len(x.split(' '))).sum())
# Out:
# 20307239

# %%
textKey = df[df["Text"].str.contains('alamat')]
textKey
# Out:
#                                                    Title  \
# 185                     BAFIA: Rafizi dipenjara 30 bulan
# 187                                     Najib mohon maaf
# 327    AirAsia minta pelanggan semak status penerbang...
# 480    "PDRM tubuh pasukan petugas khas banteras judi...
# 587                    Rangka lelaki ditemui dalam semak
# 985    Larian Sukan SEA 2017: Penganjur lanjut tarikh...
# 988      Empat dalang cuba serang penutup KL2017 didakwa
# 1102   15 Mei dengar permohonan Rafizi rujuk tiga soa...
# 1126            Pemandu lori didakwa edar dadah satu tan
# 1134   Kes muflis Shaheizy Sam ditetapkan untuk pengu...
# 1139             Annuar Musa letak jawatan Presiden KAFA
# 1201   Maklumat penghidap HIV bocor: Maafkan kami - M...
# 1254   Sultan Selangor titah papan tanda tulisan Cina...
# 1477   Pakej berisi bahan letupan dikirim dari Dublin...
# 1570   Permit ditarik balik, debat Tun Mahathir-Nazri...
# ...

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
writer = ExcelWriter('WSD_Keys.xlsx')
textKey.to_excel(writer,index=False)
writer.save()

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
searched_words = ['alamat']
TextWSD = df['Text'].apply(lambda text: [sent for sent in sent_tokenize(text)
                                       if any(True for w in word_tokenize(sent) 
                                               if w.lower() in searched_words)])
