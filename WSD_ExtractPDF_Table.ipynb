# %%
# !pip install tabula-py

# %%
import tabula

# %%
tabula.convert_into("Kata-Banyak-Makna.pdf", "WSD_Words.xlsx", output_format="xlsx")

# %%
df = tabula.read_pdf("Kata-Banyak-Makna.pdf")

# in order to print first 5 lines of Table

df.head()
# Out:
#   Unnamed: 0          PENGGUNAAN KATA BANYAK MAKNA – KATA DASAR
# 0       Kata                                  Makna Ayat Contoh
# 1     Alamat        a) Tanda a) Awan mendung alamat akan hujan.
# 2        NaN  b) Tempat tinggal b) Posmen menghantar surat b...
# 3        NaN                          alamat pada sampul surat.
# 4     Ambang  a) Waktu sebelum sesuatu  a) Setiap tahun bula...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
# Unnamed: 0                                   8 non-null object
# PENGGUNAAN KATA BANYAK MAKNA – KATA DASAR    38 non-null object
# dtypes: object(2)
# memory usage: 704.0+ bytes

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
writer = ExcelWriter('WSD_Text.xlsx')
df.to_excel(writer,index=False)
writer.save()

# %%
df = tabula.read_pdf("Kata-Banyak-Makna.pdf", multiple_tables=True)

# %%
df = tabula.read_pdf("Kata-Banyak-Makna.pdf", pages=2)

# %%
df
# Out:
#      Bencana        a) Kecelakaan,malapetaka  \
# 0        NaN       b) Pengkhianatan,gangguan
# 1        NaN                             NaN
# 2        NaN                             NaN
# 3        NaN                             NaN
# 4     Bernas                       a) Berisi
# 5        NaN      b) Subur,penuh berisi(padi
# 6        NaN                    atau gandum)
# 7     Bidang            a) Penjodoh bilangan
# 8        NaN         b) Permukaan yang datar
# 9        NaN                 c) Ukuran lebar
# 10       NaN       d) Jurusan, disiplin ilmu
# 11       NaN       e) Lapangan yang diceburi
# 12       NaN                             NaN
# 13     Bulat          a) Bentuk seperti bola
# 14       NaN  b) Bundar seperti duit syiling
# 15       NaN                       atau roda
# 16       NaN                        c) Tekad
# 17       NaN                             NaN
# 18  Canggung           a) Kekok, tidak mahir
# 19       NaN              b) Kurang sempurna
# ...
